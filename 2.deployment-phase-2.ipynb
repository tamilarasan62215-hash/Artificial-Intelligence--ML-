# %%
import pickle          # py(library)

# %%
loaded_model=pickle.load(open("finalized_model_linear.sav",'rb'))  # load datas in read binary
result=loaded_model.predict([[55]])     #y=9360X(x)+26777 actual valu X(x)predict valu 
result                                  # final result for experience staff salary
# Out:
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[541591.76208185]])
